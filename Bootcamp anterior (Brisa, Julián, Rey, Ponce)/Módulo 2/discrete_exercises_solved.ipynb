# %% [markdown]
# 1. According to the maintenance department of a university, the number of toilet blockages obeys a Poisson distribution with an average of $6$ failures everyday. Then what is the approximate probability that there will be $4$ failures during a particular day?

# %% [markdown]
# Tenemos nuestra $\lambda$= 6 y nuestra $n$=4. Por ende, la probailidad de que ocurran 4 fallas en un día en particular es:
#
# $f(4, 6) = \frac{6 ^{4} e^{-6}}{4 !} \approx 0.134.$

# %%
from scipy.stats import poisson
poisson.pmf(4,6)
# Out:
# 0.13385261753998332

# %% [markdown]
# ---
#
#
# 2. Find the expected value of the number of tails when a fair coin is flipped once.

# %% [markdown]
# Cuando echamos un volado una única vez, el número de sellos (tails) puede ser 1 o 0, cada uno con probabilidad $p=\frac{1}{2}$. Este tipo de distribución de probabilidad se le llama distribución Benoulli, la cual es un distribución discreta donde una variable $X$ puede ser 1 (éxito) con probabilidad $p$ o 0(fracaso) con probabilildad $1-p$.
#
# Recordemos el que valor esperado* de una Bernoulli esta dado por $E[X]=p$
#
# Dado eso, el valor esperado cuando aventamos nuestra moneda una sola vez es:
#
# $E[X]=\frac{1}{2}$
#
# *es la media que puede llegar a darse de determinado experimento después de varias repeticiones del mismo

# %%
from scipy.stats import bernoulli
bernoulli.mean(.5)
# Out:
# 0.5

# %% [markdown]
# ---
#
#
# 3. Reina throws a fair die 16 times. What is the sum of the expected value and variance of the number of trials where she gets a multiple of 3?

# %% [markdown]
# Supongamos que $X$ es el número de resultados de tener múltiplos de 3. Sabemos que el dado tiene dos multiplos de 3 que son 3 y 6 por lo cual la probablidad de que ella obtenga multiplo de 3 en una tirada es $p=\frac26=\frac13$.
#
# Por ende, $X$ sigue una distribución Binomial $X \ B(16,\frac13)$. Por ello el valor esperado y la varianza de $X$ son:
#
# $E[X]=16\times\frac{1}{3}=\frac{16}{3}$
#
# $V(X)=16\times(\frac{1}{3}-\frac{1}{3}^{2})=\frac{32}{9}$ \\
# ​
# La respuesta final es
# $E[X]+V(X)=\frac{80}{9}.$

# %%
from scipy.stats import binom
mean = binom.mean(16,1/3)
var =binom.var(16,1/3)
print(mean + var)
# Out:
# 8.88888888888889

# %% [markdown]
# ---
#
#
# 4. Assume that bacteria of a species called $X$ are randomly distributed in a certain river $Y$ according to the Poisson distribution with an average concentration of 16 per 40 ml of water. If we draw 10 ml of water from the river using a test tube, what is the approximate probability that the number of bacteria $X$ in the sample is exactly $4$?

# %% [markdown]
# Siguiendo las propiedades de una distribución Poisson, el numero de bacteiars contenidas en 10 ml de agua también obedece a una poisson con $\lambda$ = 16 x $\frac{10}{40}$ = 4. Entonces, la función de probabilidad esta dada por
#
#
# $f(n; \lambda_{10}) = \frac{(\lambda_{10})^{n} e^{-\lambda_{10}}}{n!}.$
# ​
#
# Por ello, la probabilidad de que el numero de bacteria $X$ en la muestra sea 4 puede obtenerse de la siguiente manera: \\
# $f(4; \lambda_{10}) = \frac{\lambda_{10}^{4} e^{-\lambda{10}}}{4!} = \frac{4 ^{4} e^{-4}}{4!} \approx 0.195.$

# %%
from scipy.stats import poisson
poisson.pmf(4,4)
# Out:
# 0.19536681481316454

# %% [markdown]
# ---
# 5. Consider the Bernoulli distribution with $p=0.8$. If a sequence of $10$
# trials are done, what is the expected value of the number of successes that occur?

# %% [markdown]
# Fácilmente podemos obtener que cuando hacemos 10 pruebas con $p = .8$, el valor esperado estará dado por
#
#
#
# $E[10X]=10E[X]=10\times0.8=8.$
#
# De hecho, la probabilidad de la distribución de los éxitos cuando se hace más de una prueba de eventos Bernoulli se le conoce como distribución binomial, la cual se denota por $B(n,p)$. El valor esperao de la binomial esta dado por
#
# $ E[X]=np$
#
# La cual corresponde al resultado de arriba

# %%
#Conocemos el numero de pruebas (n = 10)
#Conocemos la probabilidad (p = .8)
#Vemos que se comporta como el valor esperado de una binomial dado los datos que tenemos
p = .8
n = 10
p*n
# Out:
# 8.0
