# %%
from github import Github

# %%
 g = Github("36b2e607f1d0f03bd11537aa4a80dc9edd482aae")

# %%
user = g.get_user("losarchivosmauricio")

# %%
print(user.name)
# Out:
# None

# %%
#Encontrar el mal chiste que esta escondido en los archivos.
# Dentro de los folders de la cuenta: ironhack-datalabs
# del repositorio Scavenger

repo = g.get_repo("ironhack-datalabs/scavenger")

# %%
contenidos = repo.get_contents('')

# %%
for contenido in contenidos:
    #Sacar el path del archivo
    print(contenido.path)
    if contenido.type == 'dir':
        print(contenidos.extend(repo.get_contents(contenido.path)))
    #if contenido.path.endswith('scavengerhunt'):
    #    print(contenido.path)
    #Validar si endsWith('Scavenger Hunt')
    #if contenido.path
    #contenido.get_contents()
    #print(contenido.type)
    #archivo_contenido = repo.get_contents(contenido.path)

    #print(archivo_contenido.decoded_content)
    #break
# Out:
# .gitignore
# 15024
# None
# 15534
# None
# 17020
# None
# 30351
# None
# 40303
# None
# 44639
# None
# 45525
# None
# 47222
# None
# 47830
# None
# 49418
# None
# 50896
# None
# 55417
# None
# 55685
# None
# 60224
# None
# 64880
# None
# 66032
# None
# 68848
# None
# 70751
# None
# 70985
# None
# 88596
# None
# 89046
# None
# 89338
# None
# 91701
# None
# 97881
# None
# 98750
# None
# 15024/.0006.scavengerhunt
# 15024/40
# 15024/74
# 15024/99
# 15534/.0008.scavengerhunt
# 15534/.0012.scavengerhunt
# 15534/2
# 15534/98
# 17020/.0007.scavengerhunt
# 17020/46
# 17020/97
# 30351/.0021.scavengerhunt
# 30351/22
# 30351/96
# 40303/.0022.scavengerhunt
# 40303/51
# 40303/65
# 44639/.0005.scavengerhunt
# 44639/76
# 44639/91
# 45525/.0018.scavengerhunt
# 45525/67
# 45525/90
# 47222/.0016.scavengerhunt
# 47222/.0024.scavengerhunt
# 47222/7
# 47222/89
# 47830/.0010.scavengerhunt
# 47830/66
# 47830/85
# 49418/.0014.scavengerhunt
# 49418/30
# 49418/38
# 49418/84
# 50896/.0011.scavengerhunt
# ...

# %%
#while
import feedparser

# %%
wired = feedparser.parse('https://www.wired.com/feed/rss')

# %%
print(wired)
# Out:
# {'feed': {'title': 'Wired', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.wired.com/feed/rss', 'value': 'Wired'}, 'subtitle': 'The latest from www.wired.com', 'subtitle_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.wired.com/feed/rss', 'value': 'The latest from www.wired.com'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.wired.com'}, {'href': 'https://www.wired.com/feed/rss', 'rel': 'self', 'type': 'application/atom+xml'}], 'link': 'https://www.wired.com', 'rights': '© Condé Nast 2020', 'rights_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.wired.com/feed/rss', 'value': '© Condé Nast 2020'}, 'language': 'en', 'updated': 'Sat, 09 May 2020 17:14:20 +0000', 'updated_parsed': time.struct_time(tm_year=2020, tm_mon=5, tm_mday=9, tm_hour=17, tm_min=14, tm_sec=20, tm_wday=5, tm_yday=130, tm_isdst=0)}, 'entries': [{'title': 'The 5G Coronavirus Conspiracy Theory Has Taken a Dark Turn', 
# ...

# %%
wired.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'subtitle', 'subtitle_detail', 'links', 'link', 'rights', 'rights_detail', 'language', 'updated', 'updated_parsed'])

# %%
wired.feed.title_detail
# Out:
# {'type': 'text/plain',
#  'language': None,
#  'base': 'https://www.wired.com/feed/rss',
#  'value': 'Wired'}

# %%
wired.feed.icon
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/feedparser.py in __getattr__(self, key)
#     397         try:
# --> 398             return self.__getitem__(key)
#     399         except KeyError:
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/feedparser.py in __getitem__(self, key)
#     355                 return dict.__getitem__(self, realkey)
# --> 356         return dict.__getitem__(self, key)
#     357
#
# KeyError: 'icon'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b3f6cac08e5f> in <module>
# ----> 1 wired.feed.icon
#       2
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/feedparser.py in __getattr__(self, key)
#     398             return self.__getitem__(key)
# ...

# %%
len(wired.entries)
# Out:
# 50

# %%
wired.entries[0].title
# Out:
# 'The 5G Coronavirus Conspiracy Theory Has Taken a Dark Turn'

# %%
for entrada in wired.entries:
    print(entrada.title)
# Out:
# The 5G Coronavirus Conspiracy Theory Has Taken a Dark Turn
# Space Photos of the Week: Europa\! Attempt No Landing There
# Zoom Security Gets a Boost With Keybase Acquisition
# 10 Best Wireless Earbuds WIRED Has Tried (True Wireless)
# *The Last Unicorn* Is a Work of Art
# Trump Guns for Chinese Telecoms but Doesn't Have a Real Plan
# 'Call of Duty: Modern Warfare 2' Is Still an Infuriating Relic
# 18 Last-Minute Mother's Day Gift Ideas and Deals (2020)
# Is Online Grocery Shopping Better for the Planet?
# 15 Best Weekend Deals: Headphones, Kitchen Essentials, and More
# 300 Drones Illuminate the Sky to Honor Health Care Workers
# Ways to Stay Calm During Quarantine: Candles, Plants, and Other Tips
# Watson's Creator Wants to Teach AI a New Trick: Common Sense
# Covid-19 Casts a Dark Cloud Over the Flying Car Future
# Microsoft Is Starting to Tease Xbox Series X Games
# Defcon Is Canceled
# The Year the Internet Thought I Was MacKenzie Bezos
# ...

# %%
import pandas as pd
df = pd.DataFrame(wired.entries)
df.head(10)
# Out:
#                                                title  \
# 0  The 5G Coronavirus Conspiracy Theory Has Taken...
# 1  Space Photos of the Week: Europa\! Attempt No ...
# 2  Zoom Security Gets a Boost With Keybase Acquis...
# 3  10 Best Wireless Earbuds WIRED Has Tried (True...
# 4                *The Last Unicorn* Is a Work of Art
# 5  Trump Guns for Chinese Telecoms but Doesn't Ha...
# 6  'Call of Duty: Modern Warfare 2' Is Still an I...
# 7  18 Last-Minute Mother's Day Gift Ideas and Dea...
# 8  Is Online Grocery Shopping Better for the Planet?
# 9  15 Best Weekend Deals: Headphones, Kitchen Ess...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
# 5  {'type': 'text/plain', 'language': None, 'base...
# ...
