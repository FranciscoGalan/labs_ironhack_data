# %%
import pandas as panditasbb
import numpy as np

# %%
animals = panditasbb.read_csv('data/animals.csv')

# %%
animals['bodywtkg'] = animals['bodywt'] * 0.45359237
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg
# 0    3.385   44.500  Arctic_fox   20.184860
# 1    0.480   15.499  Owl_monkey    7.030228
# 2    1.350    8.100      Beaver    3.674098
# 3  464.983  423.012         Cow  191.875016
# 4   36.328  119.498   Gray_wolf   54.203381

# %%
animals['wtratio'] = animals['bodywt'] / animals['brainwt']

# %%
animals['wtratiozerocheck'] = np.where(animals['brainwt'] != 0, animals['bodywt'] / animals['brainwt'], 0)

# %%
animals.iat[28, 0] = 0

# %%
animals['sumatoria'] = animals.sum(axis=1)

# %%
vehicles = panditasbb.read_csv('data/vehicles/vehicles.csv')

# %%
vehicles.groupby(['Transmission'])

# %%
agrupados1 = vehicles.groupby(['Transmission'])['Highway MPG', 'City MPG', 'Combined MPG'].mean()
# Out:
# <ipython-input-15-35265d4188a6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   agrupados1 = vehicles.groupby(['Transmission'])['Highway MPG', 'City MPG', 'Combined MPG'].mean()

# %%
agrupados2 = vehicles.groupby(['Fuel Type', 'Cylinders'])['CO2 Emission Grams/Mile'].median()

# %%
agrupados2['CNG',4.0]
# Out:
# 253.19732142857143

# %%
agregados3 = vehicles.groupby(['Fuel Type'])['Combined MPG'].agg(['mean', 'median', 'std'])

# %%
import statistics
def aggregacion_multimoda(x):
    
    return(statistics.multimode(x))

# %%
vehicles.groupby(['Transmission'])['Vehicle Class'].agg(statistics.multimode)
# Out:
# Transmission
# Auto (AV)                                                              [Compact Cars]
# Auto (AV-S6)                                                           [Compact Cars]
# Auto (AV-S8)                                                           [Midsize Cars]
# Auto(A1)                                                            [Subcompact Cars]
# Auto(AM-S6)                                                            [Compact Cars]
# Auto(AM-S7)                                                        [Minicompact Cars]
# Auto(AM-S8)                                                [Compact Cars, Large Cars]
# Auto(AM-S9)                                                             [Two Seaters]
# Auto(AM5)                                                               [Two Seaters]
# Auto(AM6)                                                              [Compact Cars]
# Auto(AM7)                                                               [Two Seaters]
# ...

# %%
from scipy import stats

def agg_mode(x):
    return(stats.mode(x)[0])

# %%
vehicles.groupby(['Transmission'])['Vehicle Class'].agg(agg_mode)
# Out:
# Transmission
# Auto (AV)                                                 Compact Cars
# Auto (AV-S6)                                              Compact Cars
# Auto (AV-S8)                                              Midsize Cars
# Auto(A1)                                               Subcompact Cars
# Auto(AM-S6)                                               Compact Cars
# Auto(AM-S7)                                           Minicompact Cars
# Auto(AM-S8)                                               Compact Cars
# Auto(AM-S9)                                                Two Seaters
# Auto(AM5)                                                  Two Seaters
# Auto(AM6)                                                 Compact Cars
# Auto(AM7)                                                  Two Seaters
# Auto(AM8)                           Standard Sport Utility Vehicle 4WD
# Auto(AV-S6)                                               Midsize Cars
# ...
