# %%
# http://www.emergentmind.com/neural-network
# https://hmkcode.com/ai/backpropagation-step-by-step/
# https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %%
# Revisa la documentacion de python para poder instalar tenworflow.
# Quizas alguno de las siguientes lineas sean de utilidad, o usa la suite anaconda.
# !conda install tensorflow
# !pip install tensorflow

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and split data
from sklearn.datasets import load_iris
iris = load_iris()

# We will use length and width of petals as X to predict length and width of sepals as Y
# We also keep the labels in a vector L
X = iris.data[:, :2]
Y = iris.data[:, 2:]
L = iris.target

print("X data:", X.shape)
print("Y data:", Y.shape)
print("L data:", L.shape)

# Plot it
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(X[L==0, 0], X[L==0, 1], c='b', label='setosa')
plt.scatter(X[L==1, 0], X[L==1, 1], c='r', label='versicolor')
plt.scatter(X[L==2, 0], X[L==2, 1], c='g', label='virginica')
plt.legend()
plt.grid(True)
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.title('Input variables X')
plt.subplot(1, 2, 2)
plt.scatter(Y[L==0, 0], Y[L==0, 1], c='b', label='setosa')
plt.scatter(Y[L==1, 0], Y[L==1, 1], c='r', label='versicolor')
plt.scatter(Y[L==2, 0], Y[L==2, 1], c='g', label='virginica')
plt.legend()
plt.grid(True)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('Output variables Y')
plt.show()
# Out:
# X data: (150, 2)
# Y data: (150, 2)
# L data: (150,)

# %%
# Create a vector of indices and split it into training and test sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test, l_train, l_test = train_test_split(X, Y, L, test_size=0.2)

print("Training + validation inputs X:", x_train.shape)
print("Test inputs X:", x_test.shape)
print("Training + validation outputs Y:", y_train.shape)
print("Test outputs Y:", y_test.shape)
print("Training + validation labels l:", l_train.shape)
print("Test labels l:", l_test.shape)
# Out:
# Training + validation inputs X: (120, 2)
# Test inputs X: (30, 2)
# Training + validation outputs Y: (120, 2)
# Test outputs Y: (30, 2)
# Training + validation labels l: (120,)
# Test labels l: (30,)

# %%
# Documentación de tensorflow y keras
# https://www.tensorflow.org/
# https://keras.io/

# %%
# import tensorflow an the classes Model, Input (place-holder layer), and Dense (fully connected layer)
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# %%
# Create an MLP of two inputs x=[x1, x2], and two outputs y=[y1, y2]
i = Input(shape=(2,), name='input')
o = Dense(units=2, activation=None, name='output')(i)

MLP = Model(inputs=i, outputs=o)
MLP.summary() # print a summary of the MLP model
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Obtain weights and biases of the hidden layer
w1, b1 = MLP.layers[1].get_weights()
print("Initial weights:", w1.shape)
print(w1)
print("Initial biases", b1.shape)
print(b1)
# Out:
# Initial weights: (2, 2)
# [[-0.91564626 -0.71019924]
#  [-0.01909578  0.01968968]]
# Initial biases (2,)
# [0. 0.]

# %%
# Plot a diagram of the MLP model
from tensorflow.keras.utils import plot_model
plot_model(MLP, to_file='MLP.png')

# %%
# Here we define the optimizer and loss function
# Adam and mse in this initial example
MLP.compile(optimizer='adam', loss='mse')

# %%
# And now we train the model
# Learn to predict sepal's lenght and width from petal's lenght and width
HISTORY = MLP.fit(x=x_train, y=y_train, batch_size=1, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.2436 - val_loss: 1.1854
# Epoch 2/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.2325 - val_loss: 1.1727
# Epoch 3/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.2275 - val_loss: 1.1611
# Epoch 4/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.2068 - val_loss: 1.1499
# Epoch 5/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1982 - val_loss: 1.1414
# Epoch 6/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1860 - val_loss: 1.1299
# Epoch 7/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1769 - val_loss: 1.1158
# Epoch 8/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1666 - val_loss: 1.1089
# Epoch 9/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1524 - val_loss: 1.0959
# Epoch 10/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1434 - val_loss: 1.0835
# Epoch 11/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1366 - val_loss: 1.0745
# Epoch 12/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1246 - val_loss: 1.0635
# Epoch 13/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1123 - val_loss: 1.0533
# Epoch 14/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.1024 - val_loss: 1.0418
# Epoch 15/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0967 - val_loss: 1.0311
# Epoch 16/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0878 - val_loss: 1.0250
# Epoch 17/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0705 - val_loss: 1.0107
# Epoch 18/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0642 - val_loss: 1.0023
# Epoch 19/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.0542 - val_loss: 0.9919
# Epoch 20/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0455 - val_loss: 0.9825
# Epoch 21/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0358 - val_loss: 0.9721
# Epoch 22/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0282 - val_loss: 0.9620
# Epoch 23/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0183 - val_loss: 0.9542
# Epoch 24/100
# 96/96 [==============================] - 0s 1ms/step - loss: 1.0069 - val_loss: 0.9439
# Epoch 25/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9999 - val_loss: 0.9355
# Epoch 26/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9948 - val_loss: 0.9280
# Epoch 27/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9782 - val_loss: 0.9157
# Epoch 28/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9727 - val_loss: 0.9073
# Epoch 29/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9609 - val_loss: 0.8983
# Epoch 30/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9549 - val_loss: 0.8911
# Epoch 31/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9457 - val_loss: 0.8806
# Epoch 32/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9371 - val_loss: 0.8722
# Epoch 33/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9276 - val_loss: 0.8650
# Epoch 34/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9213 - val_loss: 0.8561
# Epoch 35/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9102 - val_loss: 0.8476
# Epoch 36/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9060 - val_loss: 0.8400
# Epoch 37/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.9012 - val_loss: 0.8311
# Epoch 38/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8889 - val_loss: 0.8233
# Epoch 39/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8826 - val_loss: 0.8149
# Epoch 40/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8706 - val_loss: 0.8077
# Epoch 41/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8632 - val_loss: 0.7996
# Epoch 42/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.8569 - val_loss: 0.7910
# Epoch 43/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8500 - val_loss: 0.7840
# Epoch 44/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8389 - val_loss: 0.7759
# Epoch 45/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8356 - val_loss: 0.7695
# Epoch 46/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8275 - val_loss: 0.7625
# Epoch 47/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8216 - val_loss: 0.7547
# Epoch 48/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8115 - val_loss: 0.7474
# Epoch 49/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8088 - val_loss: 0.7409
# Epoch 50/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7989 - val_loss: 0.7330
# Epoch 51/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7922 - val_loss: 0.7255
# Epoch 52/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7870 - val_loss: 0.7196
# Epoch 53/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7783 - val_loss: 0.7124
# Epoch 54/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7712 - val_loss: 0.7050
# Epoch 55/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7641 - val_loss: 0.6988
# Epoch 56/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7607 - val_loss: 0.6925
# Epoch 57/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7555 - val_loss: 0.6860
# Epoch 58/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7483 - val_loss: 0.6805
# Epoch 59/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7374 - val_loss: 0.6746
# Epoch 60/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7330 - val_loss: 0.6680
# Epoch 61/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7287 - val_loss: 0.6615
# Epoch 62/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7193 - val_loss: 0.6548
# Epoch 63/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7146 - val_loss: 0.6489
# Epoch 64/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7117 - val_loss: 0.6437
# Epoch 65/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.7019 - val_loss: 0.6369
# Epoch 66/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6970 - val_loss: 0.6309
# Epoch 67/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6917 - val_loss: 0.6248
# Epoch 68/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6864 - val_loss: 0.6193
# Epoch 69/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6784 - val_loss: 0.6134
# Epoch 70/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6742 - val_loss: 0.6073
# Epoch 71/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6692 - val_loss: 0.6018
# Epoch 72/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6624 - val_loss: 0.5975
# Epoch 73/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6582 - val_loss: 0.5918
# Epoch 74/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6551 - val_loss: 0.5885
# Epoch 75/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6493 - val_loss: 0.5826
# Epoch 76/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6453 - val_loss: 0.5767
# Epoch 77/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6399 - val_loss: 0.5728
# Epoch 78/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6329 - val_loss: 0.5708
# Epoch 79/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6286 - val_loss: 0.5605
# Epoch 80/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6224 - val_loss: 0.5550
# Epoch 81/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6161 - val_loss: 0.5507
# Epoch 82/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6108 - val_loss: 0.5456
# Epoch 83/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.6055 - val_loss: 0.5409
# Epoch 84/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6012 - val_loss: 0.5372
# Epoch 85/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5979 - val_loss: 0.5329
# Epoch 86/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5955 - val_loss: 0.5263
# Epoch 87/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5883 - val_loss: 0.5235
# Epoch 88/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5839 - val_loss: 0.5180
# Epoch 89/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5803 - val_loss: 0.5131
# Epoch 90/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5762 - val_loss: 0.5115
# Epoch 91/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5714 - val_loss: 0.5055
# Epoch 92/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5666 - val_loss: 0.5071
# Epoch 93/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5638 - val_loss: 0.4986
# Epoch 94/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5579 - val_loss: 0.4958
# Epoch 95/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5554 - val_loss: 0.4899
# Epoch 96/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5518 - val_loss: 0.4837
# Epoch 97/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5485 - val_loss: 0.4822
# Epoch 98/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5413 - val_loss: 0.4783
# Epoch 99/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5363 - val_loss: 0.4779
# Epoch 100/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.5326 - val_loss: 0.4689

# %%
# Plot loss (The object MLP keeps track of the training and validation performance)
plt.figure(figsize=(12, 5))
plt.plot(MLP.history.history['loss'], label='Training', linewidth=2)
plt.plot(MLP.history.history['val_loss'], label='Validation', linewidth=2)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Obtain weights and biases of the hidden layer after training
w1, b1 = MLP.layers[1].get_weights()
print("Initial weights:", w1.shape)
print(w1)
print("Initial biases", b1.shape)
print(b1)
# Out:
# Initial weights: (2, 2)
# [[ 1.0462568   0.5464815 ]
#  [-0.84881043 -0.59948444]]
# Initial biases (2,)
# [ 0.22513337 -0.15968129]

# %%
# Use the trained model to compute the average test loss
MLP.evaluate(x=x_test, y=y_test, verbose=False)
# Out:
# 0.48199865221977234

# %%
# Now generate the predictions on the test set
y_test_hat = MLP.predict(x=x_test)
print(y_test_hat.shape)
# Out:
# (30, 2)

# %%
# Plot y_test_hat
plt.scatter(y_test[l_test==0, 0], y_test[l_test==0, 1], c='b', label='set y')
plt.scatter(y_test[l_test==1, 0], y_test[l_test==1, 1], c='r', label='ver y')
plt.scatter(y_test[l_test==2, 0], y_test[l_test==2, 1], c='g', label='vir y')

plt.scatter(y_test_hat[l_test==0, 0], y_test_hat[l_test==0, 1], c='b', marker='+', label='set y_h')
plt.scatter(y_test_hat[l_test==1, 0], y_test_hat[l_test==1, 1], c='r', marker='+', label='ver y_h')
plt.scatter(y_test_hat[l_test==2, 0], y_test_hat[l_test==2, 1], c='g', marker='+', label='vir y_h')

plt.legend()
plt.grid(True)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('Output variables')
plt.show()

# %%
# Create a larger MLP
i = Input(shape=(2,), name='input')
h = Dense(units=32, activation='relu', name='hidden1')(i)
h = Dense(units=16, activation='relu', name='hidden2')(h)
h = Dense(units=8, activation='relu', name='hidden3')(h)
o = Dense(units=2, activation=None, name='output')(h)

MLP = Model(inputs=i, outputs=o)
MLP.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 2)]               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 32)                96
# _________________________________________________________________
# hidden2 (Dense)              (None, 16)                528
# _________________________________________________________________
# hidden3 (Dense)              (None, 8)                 136
# _________________________________________________________________
# output (Dense)               (None, 2)                 18
# =================================================================
# Total params: 778
# Trainable params: 778
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile it
MLP.compile(optimizer='adam', loss='mse')

# %%
# Train it
MLP.fit(x=x_train, y=y_train, batch_size=1, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 1s 3ms/step - loss: 4.3913 - val_loss: 0.9538
# Epoch 2/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.8870 - val_loss: 0.8504
# Epoch 3/100
# 96/96 [==============================] - 0s 2ms/step - loss: 1.0015 - val_loss: 0.6904
# Epoch 4/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.8335 - val_loss: 0.5686
# Epoch 5/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6951 - val_loss: 0.4494
# Epoch 6/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.4226 - val_loss: 0.3494
# Epoch 7/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.5355 - val_loss: 0.3739
# Epoch 8/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.3327 - val_loss: 0.2933
# Epoch 9/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2818 - val_loss: 0.2687
# Epoch 10/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2362 - val_loss: 0.2206
# Epoch 11/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2679 - val_loss: 0.2250
# Epoch 12/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2273 - val_loss: 0.2126
# Epoch 13/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2457 - val_loss: 0.2639
# Epoch 14/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.3156 - val_loss: 0.2129
# Epoch 15/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.3051 - val_loss: 0.2942
# Epoch 16/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2169 - val_loss: 0.2127
# Epoch 17/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2384 - val_loss: 0.2202
# Epoch 18/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2198 - val_loss: 0.2210
# Epoch 19/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.2270 - val_loss: 0.2488
# Epoch 20/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2175 - val_loss: 0.2799
# Epoch 21/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1708 - val_loss: 0.3366
# Epoch 22/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2702 - val_loss: 0.2265
# Epoch 23/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2751 - val_loss: 0.2862
# Epoch 24/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2076 - val_loss: 0.2775
# Epoch 25/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2674 - val_loss: 0.2098
# Epoch 26/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2199 - val_loss: 0.2917
# Epoch 27/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2399 - val_loss: 0.2116
# Epoch 28/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2000 - val_loss: 0.2279
# Epoch 29/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1766 - val_loss: 0.2100
# Epoch 30/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1953 - val_loss: 0.2157
# Epoch 31/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2025 - val_loss: 0.2087
# Epoch 32/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2572 - val_loss: 0.2444
# Epoch 33/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1868 - val_loss: 0.2041
# Epoch 34/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1891 - val_loss: 0.2199
# Epoch 35/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2601 - val_loss: 0.2163
# Epoch 36/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.3507 - val_loss: 0.3513
# Epoch 37/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2152 - val_loss: 0.2002
# Epoch 38/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2318 - val_loss: 0.2145
# Epoch 39/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1791 - val_loss: 0.3891
# Epoch 40/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2354 - val_loss: 0.3105
# Epoch 41/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2222 - val_loss: 0.2841
# Epoch 42/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1695 - val_loss: 0.2886
# Epoch 43/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1710 - val_loss: 0.3003
# Epoch 44/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2164 - val_loss: 0.2361
# Epoch 45/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2308 - val_loss: 0.2063
# Epoch 46/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2070 - val_loss: 0.2027
# Epoch 47/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1868 - val_loss: 0.2175
# Epoch 48/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2112 - val_loss: 0.3979
# Epoch 49/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2314 - val_loss: 0.2050
# Epoch 50/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1861 - val_loss: 0.1999
# Epoch 51/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2614 - val_loss: 0.2117
# Epoch 52/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2246 - val_loss: 0.1965
# Epoch 53/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1867 - val_loss: 0.1988
# Epoch 54/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1972 - val_loss: 0.2075
# Epoch 55/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2427 - val_loss: 0.2798
# Epoch 56/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1745 - val_loss: 0.1972
# Epoch 57/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2029 - val_loss: 0.2328
# Epoch 58/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2161 - val_loss: 0.2110
# Epoch 59/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2261 - val_loss: 0.2039
# Epoch 60/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2052 - val_loss: 0.1993
# Epoch 61/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1817 - val_loss: 0.2218
# Epoch 62/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.1894 - val_loss: 0.2674
# Epoch 63/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2742 - val_loss: 0.3750
# Epoch 64/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2285 - val_loss: 0.1964
# Epoch 65/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2033 - val_loss: 0.2050
# Epoch 66/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2482 - val_loss: 0.2668
# Epoch 67/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2312 - val_loss: 0.2051
# Epoch 68/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2122 - val_loss: 0.2330
# Epoch 69/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2490 - val_loss: 0.2526
# Epoch 70/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2472 - val_loss: 0.2287
# Epoch 71/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1878 - val_loss: 0.1953
# Epoch 72/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2214 - val_loss: 0.2051
# Epoch 73/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1732 - val_loss: 0.1960
# Epoch 74/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2333 - val_loss: 0.2144
# Epoch 75/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1989 - val_loss: 0.2163
# Epoch 76/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1982 - val_loss: 0.2863
# Epoch 77/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2074 - val_loss: 0.3216
# Epoch 78/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2313 - val_loss: 0.2190
# Epoch 79/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1681 - val_loss: 0.1940
# Epoch 80/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2194 - val_loss: 0.2098
# Epoch 81/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2026 - val_loss: 0.2572
# Epoch 82/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2885 - val_loss: 0.2976
# Epoch 83/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2025 - val_loss: 0.2702
# Epoch 84/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.2021 - val_loss: 0.1980
# Epoch 85/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1801 - val_loss: 0.2090
# Epoch 86/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2222 - val_loss: 0.2507
# Epoch 87/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1606 - val_loss: 0.1964
# Epoch 88/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1964 - val_loss: 0.2583
# Epoch 89/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1994 - val_loss: 0.2821
# Epoch 90/100
# 96/96 [==============================] - 0s 1ms/step - loss: 0.1749 - val_loss: 0.2063
# Epoch 91/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1855 - val_loss: 0.2770
# Epoch 92/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2074 - val_loss: 0.2209
# Epoch 93/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1503 - val_loss: 0.2970
# Epoch 94/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1649 - val_loss: 0.2079
# Epoch 95/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2258 - val_loss: 0.4341
# Epoch 96/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2276 - val_loss: 0.1914
# Epoch 97/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1840 - val_loss: 0.2670
# Epoch 98/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2057 - val_loss: 0.2943
# Epoch 99/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.2259 - val_loss: 0.2022
# Epoch 100/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1618 - val_loss: 0.2679

# %%
# Plot loss (The object MLP keeps track of the training and validation performance)
plt.figure(figsize=(12, 5))
plt.plot(MLP.history.history['loss'], label='Training', linewidth=2)
plt.plot(MLP.history.history['val_loss'], label='Validation', linewidth=2)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Obtain weights and biases of the hidden layer
for layer in MLP.layers[1:]:
  w, b = layer.get_weights()
  print("Weights: ", w.shape, end='\t')
  #print(w)
  print("Biases:  ", b.shape)
  #print(b)
# Out:
# Weights:  (2, 32)	Biases:   (32,)
# Weights:  (32, 16)	Biases:   (16,)
# Weights:  (16, 8)	Biases:   (8,)
# Weights:  (8, 2)	Biases:   (2,)

# %%
# Use the trained model to compute the average test loss
MLP.evaluate(x=x_test, y=y_test, verbose=False)
# Out:
# 0.2509354054927826

# %%
# Now generate the predictions on the test set
y_test_hat = MLP.predict(x=x_test)
print(y_test_hat.shape)
# Out:
# (30, 2)

# %%
# Plot y_test_hat
plt.scatter(y_test[l_test==0, 0], y_test[l_test==0, 1], c='b', label='set y')
plt.scatter(y_test[l_test==1, 0], y_test[l_test==1, 1], c='r', label='ver y')
plt.scatter(y_test[l_test==2, 0], y_test[l_test==2, 1], c='g', label='vir y')

plt.scatter(y_test_hat[l_test==0, 0], y_test_hat[l_test==0, 1], c='b', marker='+', label='set y_h')
plt.scatter(y_test_hat[l_test==1, 0], y_test_hat[l_test==1, 1], c='r', marker='+', label='ver y_h')
plt.scatter(y_test_hat[l_test==2, 0], y_test_hat[l_test==2, 1], c='g', marker='+', label='vir y_h')

plt.legend()
plt.grid(True)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('Test set and its prediction')
plt.show()

# %%
# Auxiliar function to create an MLP
def create_MLP(n_units=[2, 1], activations=None, last_activation=None):
  h = i = Input(shape=(n_units[0]))
  for units in n_units[1:-1]:
    h = Dense(units=units, activation=activations)(h)
  o = Dense(units=n_units[-1], activation=last_activation)(h)
  return Model(inputs=i, outputs=o)

# %%
# Corre el experimento 100 veces y registra el desempeño promedio y el tiempo de ejecución
loss = np.zeros((10, 2))
for ind in range(10):
  MLP = create_MLP([2, 32, 16, 8, 2], activations='relu', last_activation='relu')
  MLP.compile(optimizer='adam', loss='mse')
  MLP.fit(x=x_train, y=y_train, batch_size=1, epochs=100, verbose=0, validation_split=0.2)
  loss[ind, 0] = MLP.evaluate(x=x_train, y=y_train, verbose=False)
  loss[ind, 1] = MLP.evaluate(x=x_test, y=y_test, verbose=False)
  print(f"Run {ind+1:3d} -- ", end='')
  print(f"Train loss: {loss[ind, 0]:6.4f}", end='; ')
  print(f"Test loss: {loss[ind, 1]:6.4f}")

print("Average -- ", end='')
print(f" train loss: {loss[:, 0].mean():6.4f} +- {loss[:, 0].std():6.4f}", end='; ')
print(f" test loss: {loss[:, 1].mean():6.4f} +- {loss[:, 1].std():6.4f}")
# Out:
# Run   1 -- Train loss: 0.1099; Test loss: 0.2024
# Run   2 -- Train loss: 0.1155; Test loss: 0.2131
# Run   3 -- Train loss: 1.0347; Test loss: 1.3563
# Run   4 -- Train loss: 1.0327; Test loss: 1.3583
# Run   5 -- Train loss: 8.4225; Test loss: 9.6117
# Run   6 -- Train loss: 0.1171; Test loss: 0.2024
# Run   7 -- Train loss: 0.1813; Test loss: 0.2477
# Run   8 -- Train loss: 0.1480; Test loss: 0.2120
# Run   9 -- Train loss: 0.1705; Test loss: 0.2087
# Run  10 -- Train loss: 0.1331; Test loss: 0.2182
# Average --  train loss: 1.1465 +- 2.4509;  test loss: 1.3831 +- 2.7797
