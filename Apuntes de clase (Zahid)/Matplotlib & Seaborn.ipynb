# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_liquors = pd.read_csv('../../data_frame_liquors_2.csv')

# %%
df_liquors.head()
# Out:
#         invoice_id        date  store_number  \
# 0  INV-22970800091  2019-11-01          2569
# 1  INV-22958000044  2019-11-01          2603
# 2  INV-22975400022  2019-11-01          5857
# 3  INV-22976000009  2019-11-01          3782
# 4  INV-22951100010  2019-11-01          4678
#
#                              store_name                address          city  \
# 0   Hy-Vee Food Store #2 / Cedar Rapids    279 Collins Road NE  Cedar Rapids
# 1  Hy-Vee Wine and Spirits / Bettendorf  2890 Devils Glen Road    Bettendorf
# 2                  EZ Stop II - Dubuque    700 Rhomberg Avenue       Dubuque
# 3             Bender Foods / Guttenberg           619 S Hwy 52    Guttenberg
# 4            Fareway Stores #124 / Adel    804 Nile Kinnick Dr          Adel
#
#    zip_code                       store_location  county_number   county  ...  \
# 0     52402         POINT (-91.630677 42.027805)             57     LINN  ...
# ...

# %%
df_liquors.date.astype('datetime64[ns]')
df_liquors.date = pd.to_datetime(df_liquors.date)

# %%
df_liquors['week'] = df_liquors.date.dt.week
df_liquors.week =  np.where(df_liquors.week == 1, 53, df_liquors.week)
# Out:
# <ipython-input-5-81e7d3d119e6>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df_liquors['week'] = df_liquors.date.dt.week

# %%
df_liquors_week = df_liquors.groupby('week', as_index = False)[['sale_usd', 'bottles_sold']].sum()

# %%
ax1 = plt.subplot2grid((3, 2), (0, 0), colspan=1)
ax2 = plt.subplot2grid((3, 2), (0, 1), colspan=1)
ax3 = plt.subplot2grid((3, 2), (1, 0), colspan=2)
ax4 = plt.subplot2grid((3, 2), (2, 0), colspan=2)
plt.tight_layout()

# %%
# Típicamente se asigna con fig, axs
plt.subplots(2, 1)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
import matplotlib.pyplot as plt

x_values = range(1, 5001)
y_values = [x**3 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=2)

#Set chart title and labels
ax.set_title("Números cúbicos del 1 al 5000", fontsize=22)
ax.set_xlabel('número', fontsize=14)
ax.set_ylabel('número al cubo', fontsize=14)

#Set the range for each axis.
ax.axis([0, 5000, 0, 125_000_000_000])

# Set size of tick labels.
ax.tick_params(axis='both', labelsize=11)

plt.show()

# %%
df_liquors
# Out:
#              invoice_id       date  store_number  \
# 0       INV-22970800091 2019-11-01          2569
# 1       INV-22958000044 2019-11-01          2603
# 2       INV-22975400022 2019-11-01          5857
# 3       INV-22976000009 2019-11-01          3782
# 4       INV-22951100010 2019-11-01          4678
# ...                 ...        ...           ...
# 434255  INV-24264100023 2019-12-31          3943
# 434256  INV-24260000052 2019-12-31          4102
# 434257  INV-24263600053 2019-12-31          2663
# 434258  INV-24272000003 2019-12-31          4203
# 434259  INV-24260000037 2019-12-31          4102
#
#                                   store_name                address  \
# 0        Hy-Vee Food Store #2 / Cedar Rapids    279 Collins Road NE
# 1       Hy-Vee Wine and Spirits / Bettendorf  2890 Devils Glen Road
# 2                       EZ Stop II - Dubuque    700 Rhomberg Avenue
# 3                  Bender Foods / Guttenberg           619 S Hwy 52
# ...

# %% [markdown]
# ### STacked bar chart

# %%
import matplotlib.pyplot as plt

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, label='Men')
ax.bar(labels, women_means, width, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %% [markdown]
# # Seaborn

# %%
df_liquors['year'] = df_liquors.date.dt.year

# %%
df_liquors.head()
# Out:
#         invoice_id       date  store_number  \
# 0  INV-22970800091 2019-11-01          2569
# 1  INV-22958000044 2019-11-01          2603
# 2  INV-22975400022 2019-11-01          5857
# 3  INV-22976000009 2019-11-01          3782
# 4  INV-22951100010 2019-11-01          4678
#
#                              store_name                address          city  \
# 0   Hy-Vee Food Store #2 / Cedar Rapids    279 Collins Road NE  Cedar Rapids
# 1  Hy-Vee Wine and Spirits / Bettendorf  2890 Devils Glen Road    Bettendorf
# 2                  EZ Stop II - Dubuque    700 Rhomberg Avenue       Dubuque
# 3             Bender Foods / Guttenberg           619 S Hwy 52    Guttenberg
# 4            Fareway Stores #124 / Adel    804 Nile Kinnick Dr          Adel
#
#    zip_code                       store_location  county_number   county  ...  \
# 0     52402         POINT (-91.630677 42.027805)             57     LINN  ...
# ...

# %%
df_liquors.nlargest(10, 'state_bottle_cost')
# Out:
#              invoice_id       date  store_number  \
# 1692    INV-22959400002 2019-11-01          3354
# 278521  INV-23826800001 2019-12-11          3420
# 279153  INV-23827000002 2019-12-11          3420
# 361762  INV-24057100002 2019-12-20          3354
# 397494  INV-24203600002 2019-12-27          3354
# 25189   INV-23025800008 2019-11-05          5728
# 83748   INV-23203700037 2019-11-13          3524
# 85339   INV-23203200043 2019-11-13          5144
# 93817   INV-23249700031 2019-11-15          3354
# 267094  INV-23800200008 2019-12-10          5728
#
#                                store_name               address  \
# 1692          Sam's Club 8238 / Davenport      3845 Elmore Ave.
# 278521  Sam's Club 6344 / Windsor Heights         1101  73rd St
# 279153  Sam's Club 6344 / Windsor Heights         1101  73rd St
# 361762        Sam's Club 8238 / Davenport      3845 Elmore Ave.
# 397494        Sam's Club 8238 / Davenport      3845 Elmore Ave.
# ...

# %%
df_liquors_item = df_liquors.groupby('item_description', as_index = False)[['sale_usd', 'bottles_sold']].sum()
df_liquors_item
# Out:
#                            item_description  sale_usd  bottles_sold
# 0                                1800 Anejo   6387.80         190.0
# 1                              1800 Coconut   4011.87         173.0
# 2                             1800 Reposado  42501.72        1946.0
# 3                               1800 Silver  62894.70        2974.0
# 4                          1800 Silver Mini   1392.30          42.0
# ...                                     ...       ...           ...
# 2104                  Zaya Gran Reserva Rum   2684.16         128.0
# 2105  Zaya Gran Reserva Rum w/Ice Ball Tray    775.89          37.0
# 2106                  Ziyad White Rye DISCO    120.00           5.0
# 2107                              Zyr Vodka    270.00          12.0
# 2108                                maDIKwe    417.36          24.0
#
# [2109 rows x 3 columns]

# %%
df_liquors_item_top10 = df_liquors_item.nlargest(10, 'bottles_sold')
df_liquors_item_top10.head()
# Out:
#                     item_description    sale_usd  bottles_sold
# 783        Fireball Cinnamon Whiskey  1319089.76      434309.0
# 252                     Black Velvet  1418759.13      191112.0
# 1984            Titos Handmade Vodka  1472419.78      163958.0
# 948                    Hawkeye Vodka   668246.92      127488.0
# 398   Captain Morgan Original Spiced  1144989.22      114016.0

# %%
plt.figure(figsize = (15, 7.5))
sns.barplot(x='item_description', y='bottles_sold', data=df_liquors_item_top10)
plt.title('Botellas más vendidas')
# Out:
# Text(0.5, 1.0, 'Botellas más vendidas')

# %% [markdown]
# ### Histograma

# %%
df_liquors[df_liquors.bottles_sold < 400]
# Out:
#              invoice_id       date  store_number  \
# 0       INV-22970800091 2019-11-01          2569
# 1       INV-22958000044 2019-11-01          2603
# 2       INV-22975400022 2019-11-01          5857
# 3       INV-22976000009 2019-11-01          3782
# 4       INV-22951100010 2019-11-01          4678
# ...                 ...        ...           ...
# 434255  INV-24264100023 2019-12-31          3943
# 434256  INV-24260000052 2019-12-31          4102
# 434257  INV-24263600053 2019-12-31          2663
# 434258  INV-24272000003 2019-12-31          4203
# 434259  INV-24260000037 2019-12-31          4102
#
#                                   store_name                address  \
# 0        Hy-Vee Food Store #2 / Cedar Rapids    279 Collins Road NE
# 1       Hy-Vee Wine and Spirits / Bettendorf  2890 Devils Glen Road
# 2                       EZ Stop II - Dubuque    700 Rhomberg Avenue
# 3                  Bender Foods / Guttenberg           619 S Hwy 52
# ...

# %%
df_liquors_correlation = df_liquors[['bottles_sold', 'sale_usd', 'bottle_volume', 'week']].corr()

# %%
sns.heatmap(data=df_liquors_correlation, cmap='icefire', annot=True);

# %%
df_liquors.dtypes
# Out:
# invoice_id                     object
# date                   datetime64[ns]
# store_number                    int64
# store_name                     object
# address                        object
# city                           object
# zip_code                        int64
# store_location                 object
# county_number                   int64
# county                         object
# category                        int64
# category_name                  object
# vendor_number                   int64
# vendor_name                    object
# item_number                     int64
# item_description               object
# pack                            int64
# bottle_volume                 float64
# state_bottle_cost             float64
# state_bottle_retail           float64
# bottles_sold                  float64
# sale_usd                      float64
# volume_sold_lt                float64
# volume_sold_gallons           float64
# date_mes                        int64
# ...

# %%
sns.scatterplot(x=df_liquors.bottles_sold, y=df_liquors.sale_usd, hue=df_liquors.week);

# %%
df_liquors_item_top10[:5]
# Out:
#                     item_description    sale_usd  bottles_sold
# 783        Fireball Cinnamon Whiskey  1319089.76      434309.0
# 252                     Black Velvet  1418759.13      191112.0
# 1984            Titos Handmade Vodka  1472419.78      163958.0
# 948                    Hawkeye Vodka   668246.92      127488.0
# 398   Captain Morgan Original Spiced  1144989.22      114016.0

# %%
fig, axs = plt.subplots(2, 2)

# %%
np.linspace(0, 2, 100)
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
fig, ax = plt.subplots()  
ax.plot(x, x)  
ax.plot(x, x**2)  
ax.plot(x, x**3)
plt.show()

# %%
sns.barplot(x = 'item_description', y = 'bottles_sold', data=df_liquors_item_top10)
# Out:
# <AxesSubplot:xlabel='item_description', ylabel='bottles_sold'>

# %%
sns.scatterplot(x = 'item_description', y = 'bottles_sold', data=df_liquors_item_top10)
# Out:
# <AxesSubplot:xlabel='item_description', ylabel='bottles_sold'>

# %%
plt.plo

# %%
import
