# %%
import requests
import time

# %% [markdown]
# ### Bitso

# %%
info = requests.get('https://api.bitso.com/v3/available_books/')

# %%
data = info.json()

# %%
data.keys()
# Out:
# dict_keys(['success', 'payload'])

# %%
data['payload'][0].keys()
# Out:
# dict_keys(['book', 'minimum_price', 'maximum_price', 'minimum_amount', 'maximum_amount', 'minimum_value', 'maximum_value', 'tick_size', 'default_chart', 'fees'])

# %% [markdown]
# ### GitHub

# %%
usuario = requests.get("https://api.github.com/users/zk47")

# %%
respuesta = usuario.json()

# %%
respuesta
# Out:
# {'login': 'zk47',
#  'id': 8164400,
#  'node_id': 'MDQ6VXNlcjgxNjQ0MDA=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8164400?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/zk47',
#  'html_url': 'https://github.com/zk47',
#  'followers_url': 'https://api.github.com/users/zk47/followers',
#  'following_url': 'https://api.github.com/users/zk47/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/zk47/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/zk47/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/zk47/subscriptions',
#  'organizations_url': 'https://api.github.com/users/zk47/orgs',
#  'repos_url': 'https://api.github.com/users/zk47/repos',
#  'events_url': 'https://api.github.com/users/zk47/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/zk47/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 23,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2014-07-15T02:20:07Z',
#  'updated_at': '2021-07-26T13:49:20Z'}

# %%
respuesta['repos_url']
# Out:
# 'https://api.github.com/users/zk47/repos'

# %%
repos = requests.get(respuesta['repos_url'])

# %%
repos.json()[0]
# Out:
# {'id': 219090396,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyMTkwOTAzOTY=',
#  'name': '1',
#  'full_name': 'zk47/1',
#  'private': False,
#  'owner': {'login': 'zk47',
#   'id': 8164400,
#   'node_id': 'MDQ6VXNlcjgxNjQ0MDA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8164400?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/zk47',
#   'html_url': 'https://github.com/zk47',
#   'followers_url': 'https://api.github.com/users/zk47/followers',
#   'following_url': 'https://api.github.com/users/zk47/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/zk47/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/zk47/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/zk47/subscriptions',
#   'organizations_url': 'https://api.github.com/users/zk47/orgs',
#   'repos_url': 'https://api.github.com/users/zk47/repos',
#   'events_url': 'https://api.github.com/users/zk47/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/zk47/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/zk47/1',
#  'description': '这里是直播平台永久回家页，有最新app下载地址。',
#  'fork': True,
#  'url': 'https://api.github.com/repos/zk47/1',
#  'forks_url': 'https://api.github.com/repos/zk47/1/forks',
#  'keys_url': 'https://api.github.com/repos/zk47/1/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/zk47/1/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/zk47/1/teams',
#  'hooks_url': 'https://api.github.com/repos/zk47/1/hooks',
#  'issue_events_url': 'https://api.github.com/repos/zk47/1/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/zk47/1/events',
#  'assignees_url': 'https://api.github.com/repos/zk47/1/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/zk47/1/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/zk47/1/tags',
#  'blobs_url': 'https://api.github.com/repos/zk47/1/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/zk47/1/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/zk47/1/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/zk47/1/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/zk47/1/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/zk47/1/languages',
#  'stargazers_url': 'https://api.github.com/repos/zk47/1/stargazers',
#  'contributors_url': 'https://api.github.com/repos/zk47/1/contributors',
#  'subscribers_url': 'https://api.github.com/repos/zk47/1/subscribers',
#  'subscription_url': 'https://api.github.com/repos/zk47/1/subscription',
#  'commits_url': 'https://api.github.com/repos/zk47/1/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/zk47/1/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/zk47/1/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/zk47/1/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/zk47/1/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/zk47/1/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/zk47/1/merges',
#  'archive_url': 'https://api.github.com/repos/zk47/1/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/zk47/1/downloads',
#  'issues_url': 'https://api.github.com/repos/zk47/1/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/zk47/1/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/zk47/1/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/zk47/1/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/zk47/1/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/zk47/1/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/zk47/1/deployments',
#  'created_at': '2019-11-02T02:02:43Z',
#  'updated_at': '2019-11-02T02:02:44Z',
#  'pushed_at': '2019-10-30T12:57:43Z',
#  'git_url': 'git://github.com/zk47/1.git',
#  'ssh_url': 'git@github.com:zk47/1.git',
#  'clone_url': 'https://github.com/zk47/1.git',
#  'svn_url': 'https://github.com/zk47/1',
#  'homepage': '',
#  'size': 81,
#  'stargazers_count': 0,
#  'watchers_count': 0,
#  'language': None,
#  'has_issues': False,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': None,
#  'allow_forking': True,
#  'is_template': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 0,
#  'open_issues': 0,
#  'watchers': 0,
#  'default_branch': 'master'}

# %%
len(repos.json())
# Out:
# 23

# %%
headers = repos.headers

# %%
headers.keys()
# Out:
# KeysView({'Server': 'GitHub.com', 'Date': 'Tue, 09 Nov 2021 03:20:56 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"8a319dcb56f953007dcd32ae9b7f941a0b7b54507cfa673f99077599f8513229"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '57', 'X-RateLimit-Reset': '1636431588', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '3', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'C906:22BF:1D6650:42E2E9:6189E918'})

# %%
# Cuándo puedes volver a mandar requests
headers['X-RateLimit-Reset']
# Out:
# '1636431588'

# %%
time.ctime(float(headers['X-RateLimit-Reset']))
# Out:
# 'Mon Nov  8 22:19:48 2021'

# %%
import pandas as pd

# %%
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
tablas = pd.read_html(url)

# %%
a = tablas[3]
a
# Out:
#    CitizenResponse                                  \
#      12345678910» 12345678910».1 12345678910».2
# 0              NaN             NaN             NaN
# 1              NaN             NaN             NaN
# 2              NaN             NaN             NaN
# 3              NaN             NaN             NaN
# 4              NaN             NaN             NaN
# 5              NaN             NaN             NaN
# 6                1             NaN               F
# 7              NaN             NaN             NaN
# 8               34             NaN              IV
# 9              NaN             NaN             NaN
# 10             NaN             NaN             NaN
# 11               1             NaN               F
# 12             NaN             NaN             NaN
# 13             NaN             NaN             NaN
# 14             NaN             NaN             NaN
# 15             NaN             NaN             NaN
# 16             NaN             NaN             NaN
# 17             NaN             NaN             NaN
# 18               2             NaN               F
# 19             NaN             NaN             NaN
# 20             NaN             NaN               F
# 21             NaN             NaN               F
# 22             NaN             NaN             NaN
# 23             NaN             NaN             NaN
# 24             NaN             NaN             NaN
# 25             NaN             NaN             NaN
# 26             NaN             NaN             NaN
# 27             NaN             NaN             NaN
# 28             NaN             NaN             NaN
# 29             NaN             NaN             NaN
# 30             NaN             NaN             NaN
# 31             NaN             NaN             NaN
# 32             NaN             NaN             NaN
# 33             NaN             NaN             NaN
# 34             NaN             NaN               F
# 35             NaN             NaN             NaN
# 36             NaN             NaN             NaN
# 37             NaN             NaN             NaN
# 38             NaN             NaN             NaN
# 39             NaN             NaN             NaN
# 40             NaN             NaN             NaN
# 41             NaN             NaN             NaN
# 42             NaN             NaN             NaN
# 43               5             NaN              IV
# 44             NaN             NaN             NaN
# 45             NaN             NaN             NaN
# 46             NaN             NaN             NaN
# 47             NaN             NaN             NaN
# 48             NaN             NaN             NaN
# 49             NaN             NaN             NaN
# 50             NaN             NaN             NaN
# 51             NaN             NaN             NaN
# 52             NaN             NaN             NaN
# 53             NaN             NaN             NaN
# 54   12345678910»   12345678910»   12345678910»
# 55             NaN             NaN             NaN
#
#                        Date & Time UTC Latitude degrees                  \
#                          12345678910»    12345678910» 12345678910».1
# 0       2021-11-09 03:50:11.716min ago            28.56               N
# 1       2021-11-09 03:42:58.023min ago             0.06               S
# 2       2021-11-09 03:40:14.326min ago            28.56               N
# 3       2021-11-09 03:39:34.127min ago            35.45               N
# 4       2021-11-09 03:31:32.035min ago             2.84               N
# 5       2021-11-09 03:19:49.346min ago            28.60               N
# 6   2021-11-09 02:59:50.01hr 06min ago            38.45               S
# 7   2021-11-09 02:54:00.91hr 12min ago            35.47               N
# 8   2021-11-09 02:53:54.11hr 12min ago            11.29               N
# 9   2021-11-09 02:48:56.61hr 17min ago            19.22               N
# 10  2021-11-09 02:37:53.01hr 28min ago             8.17               S
# 11  2021-11-09 02:37:40.01hr 28min ago            16.82               N
# 12  2021-11-09 02:37:20.01hr 29min ago             8.20               S
# 13  2021-11-09 02:19:08.61hr 47min ago             5.37               S
# 14  2021-11-09 02:11:09.01hr 55min ago            29.57               N
# 15  2021-11-09 02:09:46.91hr 56min ago            19.21               N
# 16  2021-11-09 02:09:04.81hr 57min ago            28.51               N
# 17  2021-11-09 02:04:22.32hr 02min ago            40.08               S
# 18  2021-11-09 02:00:43.02hr 05min ago            61.70               N
# 19  2021-11-09 01:57:28.12hr 09min ago            28.56               N
# 20  2021-11-09 01:33:00.82hr 33min ago            28.60               N
# 21  2021-11-09 01:29:41.62hr 36min ago            28.56               N
# 22  2021-11-09 01:15:01.52hr 51min ago            28.56               N
# 23  2021-11-09 01:08:06.32hr 58min ago            61.45               N
# 24  2021-11-09 01:07:25.52hr 59min ago            35.46               N
# 25  2021-11-09 01:01:24.03hr 05min ago            28.54               N
# 26  2021-11-09 00:59:19.63hr 07min ago            28.57               N
# 27  2021-11-09 00:53:08.03hr 13min ago            23.76               S
# 28  2021-11-09 00:41:56.23hr 24min ago            19.21               N
# 29  2021-11-09 00:33:13.23hr 33min ago            36.87               N
# 30  2021-11-09 00:31:14.23hr 35min ago            28.56               N
# 31  2021-11-09 00:30:30.63hr 36min ago            36.47               N
# 32  2021-11-09 00:25:21.73hr 41min ago            19.22               N
# 33  2021-11-09 00:22:38.23hr 43min ago            37.76               N
# 34  2021-11-09 00:07:47.43hr 58min ago            28.56               N
# 35  2021-11-09 00:05:15.04hr 01min ago             8.85               S
# 36                                 NaN              NaN             NaN
# 37                                 NaN              NaN             NaN
# 38                                 NaN              NaN             NaN
# 39  2021-11-08 23:59:47.84hr 06min ago            19.15               N
# 40  2021-11-08 23:55:41.74hr 10min ago            28.56               N
# 41  2021-11-08 23:54:10.24hr 12min ago            28.57               N
# 42  2021-11-08 23:46:44.64hr 19min ago            28.51               N
# 43  2021-11-08 23:38:06.94hr 28min ago            37.88               N
# 44  2021-11-08 23:23:22.74hr 43min ago            36.16               N
# 45  2021-11-08 23:20:29.04hr 46min ago            17.92               N
# 46  2021-11-08 23:19:15.14hr 47min ago            28.56               N
# 47  2021-11-08 23:17:56.04hr 48min ago             9.10               S
# 48  2021-11-08 23:09:41.04hr 56min ago            20.44               S
# 49  2021-11-08 23:08:34.04hr 58min ago            28.56               N
# 50  2021-11-08 23:03:56.95hr 02min ago            35.50               N
# 51  2021-11-08 23:03:14.05hr 03min ago             4.53               S
# 52  2021-11-08 22:57:32.65hr 09min ago            36.59               N
# 53                                 NaN              NaN             NaN
# 54                       12345678910»    12345678910»   12345678910»
# 55                                 NaN              NaN             NaN
#
#    Longitude degrees                       Depth km        Mag [+]  \
#        12345678910» 12345678910».1  12345678910»  12345678910»
# 0              17.83               W             11             ML
# 1             124.40               E             18              M
# 2              17.83               W             12             ML
# 3               3.62               W             18             ML
# 4             124.49               E            292              M
# 5              17.80               W             23             ML
# 6              72.42               W             54              M
# 7               3.62               W             26             ML
# 8              86.54               W             60             Mw
# 9             155.42               W             31             Ml
# 10            117.80               E             17              M
# 11             99.99               W              5              M
# 12            107.27               E             10              M
# 13            123.27               E             10             mb
# 14            113.97               W             20              M
# 15            155.41               W             32             Ml
# 16             17.86               W             31             ML
# 17            174.03               E            138              M
# 18            150.28               W              6             ML
# 19             17.84               W             14             ML
# 20             17.76               W             23             ML
# 21             17.84               W             11             ML
# 22             17.83               W             10             ML
# 23            150.67               W             60             ML
# 24              3.65               W             23             ML
# 25             17.86               W             30             ML
# 26             17.84               W             11             ML
# 27             68.06               W            127              M
# 28            155.48               W             35             ML
# 29              3.11               W             10             ML
# 30             17.84               W             11             ML
# 31            117.95               W              8             Ml
# 32            155.49               W             36             ML
# 33             14.37               E             59             ML
# 34             17.83               W             13             ML
# 35            119.09               E             83              M
# 36               NaN             NaN            NaN            NaN
# 37               NaN             NaN            NaN            NaN
# 38               NaN             NaN            NaN            NaN
# 39            155.46               W             33             Md
# 40             17.85               W             15             ML
# 41             17.85               W             12             ML
# 42             17.84               W             15             ML
# 43             32.08               E              7             ML
# 44             89.69               W              8             Md
# 45             66.75               W              6             Md
# 46             17.84               W             13             ML
# 47             79.10               W             26              M
# 48             69.07               W             99              M
# 49             17.84               W             13             ML
# 50              3.71               W              2             ML
# 51            129.95               E            152              M
# 52            116.73               W              4             Ml
# 53               NaN             NaN            NaN            NaN
# 54     12345678910»   12345678910»  12345678910»  12345678910»
# 55               NaN             NaN            NaN            NaN
#
#    Region name [+]               Last update [-] Unnamed: 12_level_0
#      12345678910»                 12345678910»       12345678910»
# 0              2.7  CANARY ISLANDS, SPAIN REGION    2021-11-09 03:54
# 1              4.2                   MOLUCCA SEA    2021-11-09 03:50
# 2              2.4  CANARY ISLANDS, SPAIN REGION    2021-11-09 03:44
# 3              2.1           STRAIT OF GIBRALTAR    2021-11-09 03:50
# 4              4.6                   CELEBES SEA    2021-11-09 03:45
# 5              3.3  CANARY ISLANDS, SPAIN REGION    2021-11-09 03:43
# 6              4.0              ARAUCANIA, CHILE    2021-11-09 03:11
# 7              1.9           STRAIT OF GIBRALTAR    2021-11-09 03:22
# 8              5.9       NEAR COAST OF NICARAGUA    2021-11-09 03:39
# 9              2.4      ISLAND OF HAWAII, HAWAII    2021-11-09 02:54
# 10             3.1     SUMBAWA REGION, INDONESIA    2021-11-09 02:45
# 11             4.1     OFFSHORE GUERRERO, MEXICO    2021-11-09 03:01
# 12             3.5               JAVA, INDONESIA    2021-11-09 02:45
# 13             4.8                     BANDA SEA    2021-11-09 02:52
# 14             4.0            GULF OF CALIFORNIA    2021-11-09 02:31
# 15             2.2      ISLAND OF HAWAII, HAWAII    2021-11-09 02:15
# 16             2.5  CANARY ISLANDS, SPAIN REGION    2021-11-09 02:18
# 17             4.4      COOK STRAIT, NEW ZEALAND    2021-11-09 02:10
# 18             3.6               SOUTHERN ALASKA    2021-11-09 02:07
# 19             2.5  CANARY ISLANDS, SPAIN REGION    2021-11-09 02:03
# 20             3.6  CANARY ISLANDS, SPAIN REGION    2021-11-09 03:31
# 21             3.2  CANARY ISLANDS, SPAIN REGION    2021-11-09 01:36
# 22             3.0  CANARY ISLANDS, SPAIN REGION    2021-11-09 01:21
# 23             2.7               SOUTHERN ALASKA    2021-11-09 01:27
# 24             2.2           STRAIT OF GIBRALTAR    2021-11-09 01:17
# 25             2.8  CANARY ISLANDS, SPAIN REGION    2021-11-09 01:11
# 26             2.6  CANARY ISLANDS, SPAIN REGION    2021-11-09 01:05
# 27             2.9            ANTOFAGASTA, CHILE    2021-11-09 01:03
# 28             2.7      ISLAND OF HAWAII, HAWAII    2021-11-09 00:57
# 29             1.5           STRAIT OF GIBRALTAR    2021-11-09 00:44
# 30             2.8  CANARY ISLANDS, SPAIN REGION    2021-11-09 00:36
# 31             2.2            CENTRAL CALIFORNIA    2021-11-09 00:40
# 32             3.4      ISLAND OF HAWAII, HAWAII    2021-11-09 00:48
# 33             2.8                 SICILY, ITALY    2021-11-09 00:35
# 34             3.4  CANARY ISLANDS, SPAIN REGION    2021-11-09 00:24
# 35             3.2      FLORES REGION, INDONESIA    2021-11-09 00:15
# 36             NaN                           NaN                 NaN
# 37             NaN                           NaN                 NaN
# 38             NaN                           NaN                 NaN
# 39             2.2      ISLAND OF HAWAII, HAWAII    2021-11-09 00:03
# 40             3.3  CANARY ISLANDS, SPAIN REGION    2021-11-09 00:17
# 41             2.6  CANARY ISLANDS, SPAIN REGION    2021-11-09 00:02
# 42             2.5  CANARY ISLANDS, SPAIN REGION    2021-11-08 23:57
# 43             4.0                CENTRAL TURKEY    2021-11-08 23:44
# 44             2.3         SOUTHEASTERN MISSOURI    2021-11-08 23:30
# 45             3.0            PUERTO RICO REGION    2021-11-08 23:50
# 46             3.0  CANARY ISLANDS, SPAIN REGION    2021-11-08 23:50
# 47             3.7    OFF COAST OF NORTHERN PERU    2021-11-08 23:26
# 48             3.1               TARAPACA, CHILE    2021-11-08 23:24
# 49             2.7  CANARY ISLANDS, SPAIN REGION    2021-11-08 23:45
# 50             2.6           STRAIT OF GIBRALTAR    2021-11-08 23:30
# 51             2.6                     BANDA SEA    2021-11-08 23:41
# 52             2.0            CENTRAL CALIFORNIA    2021-11-09 00:30
# 53             NaN                           NaN                 NaN
# 54   12345678910»                 12345678910»       12345678910»
# 55             NaN                           NaN                 NaN
